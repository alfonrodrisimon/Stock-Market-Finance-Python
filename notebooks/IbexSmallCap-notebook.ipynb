# %%
# Import Libraries
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
from ta.volatility import BollingerBands
from ta.momentum import RSIIndicator
from ta.others import daily_return,cumulative_return
from plotly.offline import init_notebook_mode
import cufflinks as cf
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import os
import requests
from bs4 import BeautifulSoup
import warnings
from tqdm.auto import tqdm

warnings.filterwarnings("ignore")
# %matplotlib inline
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %%
# Check if folder input exists

# Define the folder name
folder_name = '../input'

# Check if the folder exists
if not os.path.exists(folder_name):
    # If it doesn't exist, create the folder
    os.makedirs(folder_name)
    print(f"'{folder_name}' folder created.")
else:
    print(f"'{folder_name}' folder already exists.")
# Out:
# '../input' folder already exists.

# %%
# Check if folder tickers exists

# Define the folder name
folder_name = '../tickers'

# Check if the folder exists
if not os.path.exists(folder_name):
    # If it doesn't exist, create the folder
    os.makedirs(folder_name)
    print(f"'{folder_name}' folder created.")
else:
    print(f"'{folder_name}' folder already exists.")
# Out:
# '../tickers' folder already exists.

# %%
# Webscrapping Wikipedia table to get the IBEX 35 Growth components
page = requests.get("https://es.wikipedia.org/wiki/IBEX_Small_Cap")
soup = BeautifulSoup(page.text, 'html.parser') 
table = soup.find('table',class_="wikitable sortable")

# %%
# Convert html table to dataframe
wiki = pd.read_html(str(table))
wiki = pd.concat(wiki)
wiki.head(40)
# Out:
#    Ticker                            Empresa                Sede  \
# 0     AZK                            Azkoyen             Peralta
# 1     ADX                   Audax Renovables            Badalona
# 2   AEDAS                        AEDAS Homes              Madrid
# 3      AI                        Airtificial              Madrid
# 4     AMP                              Amper  Pozuelo de Alarcón
# 5     BKY                   Berkeley Energía              Madrid
# 6     DIA                                DIA           Las Rozas
# 7     ECR                             Ercros           Barcelona
# 8     GSJ                           San José          Pontevedra
# 9     LRE                         Lar España              Madrid
# 10    MCM                    Miquel y Costas           Barcelona
# 11    MDF                      Duro Felguera               Gijón
# 12    NEA                     Nicolás Correa              Burgos
# 13    NXT                             NEXTIL              Madrid
# 14   OHLA                               OHLA              Madrid
# 15    OLE                             Deoleo   Rivas-Vaciamadrid
# 16    PRS                              Prisa              Madrid
# 17    RIO                   Bodegas Riojanas            Cenicero
# 18   CASH                      Prosegur Cash              Madrid
# 19    DOM             Global Dominion Access              Bilbao
# 20   ENER                            Ecoener           La Coruña
# 21    GAM  General de alquiler de maquinaria              Madrid
# 22    NTH                  Naturhouse Health              Madrid
# 23   HOME                       Neinor Homes              Bilbao
# 24    ORY                    Oryzon Genomics              Madrid
# 25    REN                  Renta Corporación           Barcelona
# 26    SOL                       Soltec Power    Molina de Segura
# 27    UBS                              URBAS              Madrid
# 28    TRG                     Tubos Reunidos             Amurrio
#
#                                    Sector[3]​          ISIN
# 0                          Ingeniería y otros  ES0112458312
# 1                         Energías renovables  ES0136463017
# 2                       Inmobiliarias y otros  ES0105287009
# 3                          Ingeniería y otros  ES0152768612
# 4                      Electrónica y software  ES0109260531
# 5           Mineral, metales y transformación  AU000000BKY0
# 6                                    Comercio  ES0126775032
# 7                           Industria química  ES0125140A14
# 8                                Construcción  ES0180918015
# 9                                      SOCIMI  ES0105015012
# 10                     Papel y artes gráficas  ES0164180012
# 11                         Ingeniería y otros  ES0162600003
# 12  Fabricación y montaje de bienes de equipo  ES0166300212
# 13                  Textil, vestido y calzado  ES0126962069
# 14                               Construcción  ES0142090317
# 15                     Alimentación y bebidas  ES0110047919
# 16        Medios de comunicación y publicidad  ES0171743901
# 17                     Alimentación y bebidas  ES0115002018
# 18                            Otros servicios  ES0105229001
# 19                         Ingeniería y otros  ES0105130001
# 20                        Energías renovables  ES0105548004
# 21                            Otros servicios  ES0141571192
# 22                     Alimentación y bebidas  ES0105043006
# 23                      Inmobiliarias y otros  ES0105251005
# 24    Productos farmacéuticos y biotecnología  ES0167733015
# 25                      Inmobiliarias y otros  ES0173365018
# 26                        Energías renovables  ES0105513008
# 27                      Inmobiliarias y otros  ES0182280018
# 28  Fabricación y montaje de bienes de equipo  ES0180850416

# %%
# Add .MC to all tickers
wiki['Ticker'] = wiki['Ticker'].apply(lambda x: x + '.MC')
wiki
# Out:
#       Ticker                            Empresa                Sede  \
# 0     AZK.MC                            Azkoyen             Peralta
# 1     ADX.MC                   Audax Renovables            Badalona
# 2   AEDAS.MC                        AEDAS Homes              Madrid
# 3      AI.MC                        Airtificial              Madrid
# 4     AMP.MC                              Amper  Pozuelo de Alarcón
# 5     BKY.MC                   Berkeley Energía              Madrid
# 6     DIA.MC                                DIA           Las Rozas
# 7     ECR.MC                             Ercros           Barcelona
# 8     GSJ.MC                           San José          Pontevedra
# 9     LRE.MC                         Lar España              Madrid
# 10    MCM.MC                    Miquel y Costas           Barcelona
# 11    MDF.MC                      Duro Felguera               Gijón
# 12    NEA.MC                     Nicolás Correa              Burgos
# 13    NXT.MC                             NEXTIL              Madrid
# 14   OHLA.MC                               OHLA              Madrid
# 15    OLE.MC                             Deoleo   Rivas-Vaciamadrid
# 16    PRS.MC                              Prisa              Madrid
# 17    RIO.MC                   Bodegas Riojanas            Cenicero
# 18   CASH.MC                      Prosegur Cash              Madrid
# 19    DOM.MC             Global Dominion Access              Bilbao
# 20   ENER.MC                            Ecoener           La Coruña
# 21    GAM.MC  General de alquiler de maquinaria              Madrid
# 22    NTH.MC                  Naturhouse Health              Madrid
# 23   HOME.MC                       Neinor Homes              Bilbao
# 24    ORY.MC                    Oryzon Genomics              Madrid
# 25    REN.MC                  Renta Corporación           Barcelona
# 26    SOL.MC                       Soltec Power    Molina de Segura
# 27    UBS.MC                              URBAS              Madrid
# 28    TRG.MC                     Tubos Reunidos             Amurrio
#
#                                    Sector[3]​          ISIN
# 0                          Ingeniería y otros  ES0112458312
# 1                         Energías renovables  ES0136463017
# 2                       Inmobiliarias y otros  ES0105287009
# 3                          Ingeniería y otros  ES0152768612
# 4                      Electrónica y software  ES0109260531
# 5           Mineral, metales y transformación  AU000000BKY0
# 6                                    Comercio  ES0126775032
# 7                           Industria química  ES0125140A14
# 8                                Construcción  ES0180918015
# 9                                      SOCIMI  ES0105015012
# 10                     Papel y artes gráficas  ES0164180012
# 11                         Ingeniería y otros  ES0162600003
# 12  Fabricación y montaje de bienes de equipo  ES0166300212
# 13                  Textil, vestido y calzado  ES0126962069
# 14                               Construcción  ES0142090317
# 15                     Alimentación y bebidas  ES0110047919
# 16        Medios de comunicación y publicidad  ES0171743901
# 17                     Alimentación y bebidas  ES0115002018
# 18                            Otros servicios  ES0105229001
# 19                         Ingeniería y otros  ES0105130001
# 20                        Energías renovables  ES0105548004
# 21                            Otros servicios  ES0141571192
# 22                     Alimentación y bebidas  ES0105043006
# 23                      Inmobiliarias y otros  ES0105251005
# 24    Productos farmacéuticos y biotecnología  ES0167733015
# 25                      Inmobiliarias y otros  ES0173365018
# 26                        Energías renovables  ES0105513008
# 27                      Inmobiliarias y otros  ES0182280018
# 28  Fabricación y montaje de bienes de equipo  ES0180850416

# %%
wiki.rename(columns={'Empresa':'Name','Sector[3]\u200b':'Sector'}, inplace=True)

# %%
# Get the data for the stock index
index_list = wiki['Ticker'].tolist()

# %%
# Save all the historical data
for stock in tqdm(index_list):
    data = yf.download(stock, progress=False,multi_level_index=False,actions=True,auto_adjust=False)
    data.to_csv(f"../input/{stock}.csv",index=True)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
# Get the name of the notebook
notebook_name = os.path.basename(globals()['__vsc_ipynb_file__'])
notebook_name = notebook_name.split('-')[0]

# %%
# Save all the tickers data
wiki[['Name','Sector','Ticker']].to_csv(f"../tickers/{notebook_name}.csv",index=True)

# %%
# Configuration of different parameters of the notebook
ticker = 'ADX.MC'
year = '2025'

# %%
# Check DataFrame
stock_ticker = pd.read_csv(f"../input/{ticker}.csv",index_col="Date",parse_dates=True)
stock_ticker.head(10)
# Out:
#             Adj Close  Close  Dividends   High    Low   Open  Stock Splits  \
# Date
# 2007-04-24   9.147391   9.60        0.0   9.60   9.45   9.60           0.0
# 2007-04-25   8.861535   9.30        0.0   9.30   9.30   9.30           0.0
# 2007-04-26   8.861535   9.30        0.0   9.30   9.30   9.30           0.0
# 2007-04-27   9.147391   9.60        0.0   9.60   9.50   9.60           0.0
# 2007-04-30  10.062132  10.56        0.0  10.56  10.20  10.56           0.0
# 2007-05-02  11.338954  11.90        0.0  12.24  11.00  11.80           0.0
# 2007-05-03   9.290319   9.75        0.0  11.95   9.51  11.78           0.0
# 2007-05-04   7.718112   8.10        0.0   9.10   8.05   8.91           0.0
# 2007-05-07   7.870569   8.26        0.0   8.49   8.01   8.01           0.0
# 2007-05-08   8.185009   8.59        0.0   8.98   8.28   8.42           0.0
#
#             Volume
# Date
# 2007-04-24   15000
# 2007-04-25   12593
# 2007-04-26   18185
# 2007-04-27    9399
# 2007-04-30   95227
# 2007-05-02       0
# 2007-05-03       0
# 2007-05-04       0
# 2007-05-07       0
# 2007-05-08       0

# %%
fig = make_subplots(rows=4, cols=1,shared_xaxes=True,vertical_spacing=0.01,specs=[[{'rowspan':3,'colspan':1}],[None],[None],[{'rowspan':1,'colspan':1}]])

# Graph (1,1)
fig.add_trace(go.Scatter(x=stock_ticker.index,y=stock_ticker['Close'],mode="lines",name=f"{ticker}"),row=1, col=1)
# Update xaxis properties
fig.update_yaxes(title_text="Price", row=1, col=1)

# Graph (4,1)
fig.add_trace(go.Scatter(x=stock_ticker.index,y=stock_ticker['Volume'],mode="lines",name='Volume'),row=4, col=1)
fig.update_yaxes(title_text="Volume", row=4, col=1)

fig.update_layout(height=800, width=1300,showlegend=False,title=f"{ticker}")

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="dda3aa0e-3026-4b12-a337-f1f9f7cbee4e" class="plotly-graph-div" style="height:800px; width:1300px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dda3aa0e-3026-4b12-a337-f1f9f7cbee4e")) {                    Plotly.newPlot(                        "dda3aa0e-3026-4b12-a337-f1f9f7cbee4e",                        [{"mode":"lines","name":"ADX.MC","x":["2007-04-24T00:00:00.000000000","2007-04-25T00:00:00.000000000","2007-04-26T00:00:00.000000000","2007-04-27T00:00:00.000000000","2007-04-30T00:00:00.000000000","2007-05-02T00:00:00.000000000","2007-05-03T00:00:00.000000000","2007-05-04T00:00:00.000000000","2007-05-07T00:00:00.000000000","2007-05-08T00:00:00.000000000","2007-05-09T00:00:00.000000000","2007-05-10T00:00:00.000000000","2007-05-11T00:00:00.000000000","2007-05-14T00:00:00.000000000","2007-05-15T00:00:00.000000000","2007-05-16T00:00:00.000000000","2007-05-17T00:00:00.000000000","2007-05-18T00:00:00.000000000","2007-05-21T00:00:00.000000000","2007-05-22T00:00:00.000000000","2007-05-23T00:00:00.000000000","2007-05-24T00:00:00.000000000","2007-05-25T00:00:00.000000000","2007-05-28T00:00:00.000000000","2007-05-29T00:00:00.000000000","2007-05-30T00:00:00.000000000","2007-05-31T00:00:00.000000000","2007-06-01T00:00:00.000000000","2007-06-04T00:00:00.000000000","2007-06-05T00:00:00.000000000","2007-06-06T00:00:00.000000000","2007-06-07T00:00:00.000000000","2007-06-08T00:00:00.000000000","2007-06-11T00:00:00.000000000","2007-06-12T00:00:00.000000000","2007-06-13T00:00:00.000000000","2007-06-14T00:00:00.000000000","2007-06-15T00:00:00.000000000","2007-06-18T00:00:00.000000000","2007-06-19T00:00:00.000000000","2007-06-20T00:00:00.000000000","2007-06-21T00:00:00.000000000","2007-06-22T00:00:00.000000000","2007-06-25T00:00:00.000000000","2007-06-26T00:00:00.000000000","2007-06-27T00:00:00.000000000","2007-06-28T00:00:00.000000000","2007-06-29T00:00:00.000000000","2007-07-02T00:00:00.000000000","2007-07-03T00:00:00.000000000","2007-07-04T00:00:00.000000000","2007-07-05T00:00:00.000000000","2007-07-06T00:00:00.000000000","2007-07-09T00:00:00.000000000","2007-07-10T00:00:00.000000000","2007-07-11T00:00:00.000000000","2007-07-12T00:00:00.000000000","2007-07-13T00:00:00.000000000","2007-07-16T00:00:00.000000000","2007-07-17T00:00:00.000000000","2007-07-18T00:00:00.000000000","2007-07-19T00:00:00.000000000","2007-07-20T00:00:00.000000000","2007-07-23T00:00:00.000000000","2007-07-24T00:00:00.000000000","2007-07-25T00:00:00.000000000","2007-07-26T00:00:00.000000000","2007-07-27T00:00:00.000000000","2007-07-30T00:00:00.000000000","2007-07-31T00:00:00.000000000","2007-08-01T00:00:00.000000000","2007-08-02T00:00:00.000000000","2007-08-03T00:00:00.000000000","2007-08-06T00:00:00.000000000","2007-08-07T00:00:00.000000000","2007-08-08T00:00:00.000000000","2007-08-09T00:00:00.000000000","2007-08-10T00:00:00.000000000","2007-08-13T00:00:00.000000000","2007-08-14T00:00:00.000000000","2007-08-15T00:00:00.000000000","2007-08-16T00:00:00.000000000","2007-08-17T00:00:00.000000000","2007-08-20T00:00:00.000000000","2007-08-21T00:00:00.000000000","2007-08-22T00:00:00.000000000","2007-08-23T00:00:00.000000000","2007-08-24T00:00:00.000000000","2007-08-27T00:00:00.000000000","2007-08-28T00:00:00.000000000","2007-08-29T00:00:00.000000000","2007-08-30T00:00:00.000000000","2007-08-31T00:00:00.000000000","2007-09-03T00:00:00.000000000","2007-09-04T00:00:00.000000000","2007-09-05T00:00:00.000000000","2007-09-06T00:00:00.000000000","2007-09-07T00:00:00.000000000","2007-09-10T00:00:00.000000000","2007-09-11T00:00:00.000000000","2007-09-12T00:00:00.000000000","2007-09-13T00:00:00.000000000","2007-09-14T00:00:00.000000000","2007-09-17T00:00:00.000000000","2007-09-18T00:00:00.000000000","2007-09-19T00:00:00.000000000","2007-09-20T00:00:00.000000000 ...

# %%
# Add Technical Analysis Indicators

# Modified Moving Average 20
stock_ticker['MMA20'] = stock_ticker['Adj Close'].loc[year].rolling(20).mean() #Adj Close 20 MA

# Initialize Bollinger Bands Indicator
indicator_bb = BollingerBands(close=stock_ticker["Adj Close"].loc[year], window=20, window_dev=2)

# Bollinger Bands
stock_ticker['BB_Upper'] = indicator_bb.bollinger_hband()
stock_ticker['BB_Lower'] = indicator_bb.bollinger_lband()

# Initialize RSI Indicator
indicator_rsi = RSIIndicator(close=stock_ticker["Adj Close"].loc[year], window=14)

# RSI
stock_ticker['RSI'] = indicator_rsi.rsi()

# Daily Return
stock_ticker['Daily_Return'] = daily_return(stock_ticker["Adj Close"].loc[year])

# %%
# Plot the adjusted close price
fig = make_subplots(rows=4, cols=1,shared_xaxes=True,vertical_spacing=0.01,specs=[[{'rowspan':2,'colspan':1}],[None],[{'rowspan':1,'colspan':1}],[{'rowspan':1,'colspan':1}]])

# Graph (1,1)
fig.add_trace(go.Scatter(x=stock_ticker['Adj Close'].loc[year].index,y=stock_ticker['Adj Close'].loc[year],mode="lines",name=f'{ticker}'),row=1,col=1)
fig.add_trace(go.Scatter(x=stock_ticker['BB_Lower'].loc[year].index,y=stock_ticker['BB_Lower'].loc[year],mode="lines",name='BB_Lower'),row=1,col=1)
fig.add_trace(go.Scatter(x=stock_ticker['BB_Upper'].loc[year].index,y=stock_ticker['BB_Upper'].loc[year],mode="lines",name='BB_Upper'),row=1,col=1)
fig.add_trace(go.Scatter(x=stock_ticker['MMA20'].loc[year].index,y=stock_ticker['MMA20'].loc[year],mode="lines",name='MMA20'),row=1,col=1)
# Update xaxis properties
fig.update_yaxes(title_text="Price", row=1, col=1)

# Graph (3,1)
fig.add_trace(go.Scatter(x=stock_ticker['Volume'].loc[year].index,y=stock_ticker['Volume'].loc[year],mode="lines",name='Volume'),row=3, col=1)
fig.add_trace(go.Scatter(x=stock_ticker['Volume'].loc[year].index,y=stock_ticker['Volume'].loc[year].rolling(20).mean(),mode="lines",name='MMA20'),row=3,col=1)
fig.update_yaxes(title_text="Volume", row=3, col=1)

# Graph (4,1)
fig.add_trace(go.Scatter(x=stock_ticker['RSI'].loc[year].index,y=stock_ticker['RSI'].loc[year],mode="lines",name='RSI'),row=4, col=1)
fig.add_hline(y=30, line_width=1, line_dash="dash", line_color="green",row=4,col=1)
fig.add_hline(y=70, line_width=1, line_dash="dash", line_color="red",row=4,col=1)
fig.update_yaxes(title_text="RSI", row=4, col=1)

fig.update_layout(height=800, width=1300,showlegend=False,title=f"{ticker} {year}")

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="3ae44c71-56f9-4f72-91a1-5d91334e034a" class="plotly-graph-div" style="height:800px; width:1300px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3ae44c71-56f9-4f72-91a1-5d91334e034a")) {                    Plotly.newPlot(                        "3ae44c71-56f9-4f72-91a1-5d91334e034a",                        [{"mode":"lines","name":"ADX.MC","x":["2025-01-02T00:00:00.000000000","2025-01-03T00:00:00.000000000","2025-01-06T00:00:00.000000000","2025-01-07T00:00:00.000000000","2025-01-08T00:00:00.000000000","2025-01-09T00:00:00.000000000","2025-01-10T00:00:00.000000000","2025-01-13T00:00:00.000000000","2025-01-14T00:00:00.000000000","2025-01-15T00:00:00.000000000","2025-01-16T00:00:00.000000000","2025-01-17T00:00:00.000000000","2025-01-20T00:00:00.000000000","2025-01-21T00:00:00.000000000","2025-01-22T00:00:00.000000000","2025-01-23T00:00:00.000000000","2025-01-24T00:00:00.000000000","2025-01-27T00:00:00.000000000","2025-01-28T00:00:00.000000000","2025-01-29T00:00:00.000000000","2025-01-30T00:00:00.000000000","2025-01-31T00:00:00.000000000","2025-02-03T00:00:00.000000000","2025-02-04T00:00:00.000000000","2025-02-05T00:00:00.000000000","2025-02-06T00:00:00.000000000","2025-02-07T00:00:00.000000000","2025-02-10T00:00:00.000000000","2025-02-11T00:00:00.000000000","2025-02-12T00:00:00.000000000","2025-02-13T00:00:00.000000000","2025-02-14T00:00:00.000000000","2025-02-17T00:00:00.000000000","2025-02-18T00:00:00.000000000","2025-02-19T00:00:00.000000000","2025-02-20T00:00:00.000000000","2025-02-21T00:00:00.000000000","2025-02-24T00:00:00.000000000","2025-02-25T00:00:00.000000000","2025-02-26T00:00:00.000000000","2025-02-27T00:00:00.000000000","2025-02-28T00:00:00.000000000","2025-03-03T00:00:00.000000000","2025-03-04T00:00:00.000000000","2025-03-05T00:00:00.000000000","2025-03-06T00:00:00.000000000","2025-03-07T00:00:00.000000000","2025-03-10T00:00:00.000000000","2025-03-11T00:00:00.000000000","2025-03-12T00:00:00.000000000","2025-03-13T00:00:00.000000000","2025-03-14T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AQAAAKwc+j8BAAAArBz6PwEAAACsHPo\u002fAAAAgEFg+T8AAADAcmj5PwAAAIBBYPk\u002fAAAAIIcW+T8AAADAdJP4PwAAAIBs5\u002fc\u002fAAAAwHST+D8AAABgukn4PwAAACCwcvg\u002f\u002f\u002f\u002f\u002f301i+D8AAAAgWDn4PwAAAEAK1\u002fc\u002fAAAAwJ3v9z8AAAAg2c73PwAAAKDtfPc\u002fAAAAwPdT9z8AAACgxkv3PwAAAAAAAPg\u002fAAAAAH9q+D8AAAAg2c73PwAAAIDrUfg\u002fAAAA4CYx+D8BAAAgMQj4PwAAAAAAAPg\u002fAAAAgJMY+D8AAACgRbb3PwAAAIBs5\u002fc\u002f\u002f\u002f\u002f\u002f38739z8AAADAdr73PwAAAIDpJvk\u002fAAAAgGq8+D8AAADAzMz4PwAAAGC4Hvk\u002fAAAA4Pup+T8AAABgj8L5PwAAAIBBYPk\u002fAAAAIAaB+T8AAADgfD\u002f5PwAAAGC4Hvk\u002fAQAA4CQG+T8AAAAgWDn4PwAAACBYOfg\u002fAAAAQArX9z8AAACAbOf3PwAAAOBPjfc\u002fAAAAgD0K9z8AAACAFtn2PwAAAKBH4fY\u002fAAAAQDMz9z8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines","name":"BB_Lower","x":["2025-01-02T00:00:00.000000000","2025-01-03T00:00:00.000000000","2025-01-06T00:00:00.000000000","2025-01-07T00:00:00.000000000","2025-01-08T00:00:00.000000000","2025-01-09T00:00:00.000000000","2025-01-10T00:00:00.000000000","2025-01-13T00:00:00.000000000","2025-01-14T00:00:00.000000000","2025-01-15T00:00:00.000000000","2025-01-16T00:00:00.000000000","2025-01-17T00:00:00.000000000","2025-01-20T00:00:00.000000000","2025-01-21T00:00:00.000000000","2025-01-22T00:00:00.000000000","2025-01-23T00:00:00.000000000","2025-01-24T00:00:00.000000000","2025-01-27T00:00:00.000000000","2025-01-28T00:00:00.000000000","2025-01-29T00:00:00.000000000","2025-01-30T00:00:00.000000000","2025-01-31T00:00:00.000000000","2025-02-03T00:00:00.000000000","2025-02-04T00:00:00.000000000","2025-02-05T00:00:00.000000000","2025-02-06T00:00:00.000000000","2025-02-07T00:00:00.000000000","2025-02-10T00:00:00.000000000","2025-02-11T00:00:00.000000000","2025-02-12T00:00 ...

# %%
# Plotly
fig = make_subplots()

# Graph (1,1)
# Loop all stock files and get cummulative return for year
for stock in tqdm(index_list):
    f = os.path.join("../input", stock)
    df = pd.read_csv(f+".csv",index_col="Date",parse_dates=True)
    df['Cummulative_Return'] = cumulative_return(df["Adj Close"].loc[year])
    fig.add_trace(go.Scatter(x=df['Cummulative_Return'].loc[year].index,y=df['Cummulative_Return'].loc[year],mode="lines",name=stock.split('.')[0]),row=1,col=1)

# Update xaxis properties
fig.update_yaxes(title_text="Return", row=1, col=1)

fig.update_layout(height=800, width=1300,showlegend=True,title=f"Cummulative Returns {ticker} for {year}")

fig.show()
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="d064d666-b920-4300-82f1-9c835757a3de" class="plotly-graph-div" style="height:800px; width:1300px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d064d666-b920-4300-82f1-9c835757a3de")) {                    Plotly.newPlot(                        "d064d666-b920-4300-82f1-9c835757a3de",                        [{"mode":"lines","name":"AZK","x":["2025-01-02T00:00:00.000000000","2025-01-03T00:00:00.000000000","2025-01-06T00:00:00.000000000","2025-01-07T00:00:00.000000000","2025-01-08T00:00:00.000000000","2025-01-09T00:00:00.000000000","2025-01-10T00:00:00.000000000","2025-01-13T00:00:00.000000000","2025-01-14T00:00:00.000000000","2025-01-15T00:00:00.000000000","2025-01-16T00:00:00.000000000","2025-01-17T00:00:00.000000000","2025-01-20T00:00:00.000000000","2025-01-21T00:00:00.000000000","2025-01-22T00:00:00.000000000","2025-01-23T00:00:00.000000000","2025-01-24T00:00:00.000000000","2025-01-27T00:00:00.000000000","2025-01-28T00:00:00.000000000","2025-01-29T00:00:00.000000000","2025-01-30T00:00:00.000000000","2025-01-31T00:00:00.000000000","2025-02-03T00:00:00.000000000","2025-02-04T00:00:00.000000000","2025-02-05T00:00:00.000000000","2025-02-06T00:00:00.000000000","2025-02-07T00:00:00.000000000","2025-02-10T00:00:00.000000000","2025-02-11T00:00:00.000000000","2025-02-12T00:00:00.000000000","2025-02-13T00:00:00.000000000","2025-02-14T00:00:00.000000000","2025-02-17T00:00:00.000000000","2025-02-18T00:00:00.000000000","2025-02-19T00:00:00.000000000","2025-02-20T00:00:00.000000000","2025-02-21T00:00:00.000000000","2025-02-24T00:00:00.000000000","2025-02-25T00:00:00.000000000","2025-02-26T00:00:00.000000000","2025-02-27T00:00:00.000000000","2025-02-28T00:00:00.000000000","2025-03-03T00:00:00.000000000","2025-03-04T00:00:00.000000000","2025-03-05T00:00:00.000000000","2025-03-06T00:00:00.000000000","2025-03-07T00:00:00.000000000","2025-03-10T00:00:00.000000000","2025-03-11T00:00:00.000000000","2025-03-12T00:00:00.000000000","2025-03-13T00:00:00.000000000","2025-03-14T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAAAAAKgefr95x+S\u002fqB5+v3nH5L+oHn6\u002fecf0P1Q2M646Kw9ArD4pvT4r\\u002f14Jj4wuEkCyBPFi8xMWQOncS4uLLiJAlMjgmuKsKECY1+TMpgYoQHbzUdYxNTFA3n8iqQN7M0B281HWMTUxQGyWKPSpgTJANksU+tTANUDUcB53PyE0QDZLFPrUwDVA1HAedz8hNEA="},"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines","name":"ADX","x":["2025-01-02T00:00:00.000000000","2025-01-03T00:00:00.000000000","2025-01-06T00:00:00.000000000","2025-01-07T00:00:00.000000000","2025-01-08T00:00:00.000000000","2025-01-09T00:00:00.000000000","2025-01-10T00:00:00.000000000","2025-01-13T00:00:00.000000000","2025-01-14T00:00:00.000000000","2025-01-15T00:00:00.000000000","2025-01-16T00:00:00.000000000","2025-01-17T00:00:00.000000000","2025-01-20T00:00:00.000000000","2025-01-21T00:00:00.000000000","2025-01-22T00:00:00.000000000","2025-01-23T00:00:00.000000000","2025-01-24T00:00:00.000000000","2025-01-27T00:00:00.000000000","2025-01-28T00:00:00.000000000","2025-01-29T00:00:00.000000000","2025-01-30T00:00:00.000000000","2025-01-31T00:00:00.000000000","2025-02-03T00:00:00.000000000","2025-02-04T00:00:00.000000000","2025-02-05T00:00:00.000000000","2025-02-06T00:00:00.000000000","2025-02-07T00:00:00.000000000","2025-02-10T00:00:00.000000000","2025-02-11T00:00:00.000000000","2025-02-12T00:00:00.000000000","2025-02-13T00:00:00.000000000","2025-02-14T00:00:00.000000000","2025-02-17T00:00:00.000000000","2025-02-18T00:00:00.0 ...

# %%
# Create also table of cummulative returns
list = []

for stock in tqdm(index_list):
    f = os.path.join("../input", stock)
    df = pd.read_csv(f+".csv",index_col="Date",parse_dates=True)
    df['Cummulative_Return'] = cumulative_return(df["Adj Close"].loc[year])
    list.append([df.loc[year].tail(1).index.item(),stock.split('.csv')[0],df["Cummulative_Return"].loc[year].iloc[-1]])


cum = pd.DataFrame(list, columns=['Date','Ticker','Cummulative_Return'])
cum = wiki[['Ticker','Name']].merge(cum,on='Ticker')
cum.sort_values(by=['Cummulative_Return'],ignore_index=True, ascending=False).head(30)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
#       Ticker                               Name       Date  Cummulative_Return
# 0     DIA.MC                                DIA 2025-03-14       114279.084321
# 1     ORY.MC                    Oryzon Genomics 2025-03-14           91.078558
# 2     PRS.MC                              Prisa 2025-03-14           28.052808
# 3     BKY.MC                   Berkeley Energía 2025-03-14           27.860693
# 4      AI.MC                        Airtificial 2025-03-14           27.366259
# 5     TRG.MC                     Tubos Reunidos 2025-03-14           26.129669
# 6     NEA.MC                     Nicolás Correa 2025-03-14           24.415587
# 7     REN.MC                  Renta Corporación 2025-03-14           23.030295
# 8     AMP.MC                              Amper 2025-03-14           22.448973
# 9    CASH.MC                      Prosegur Cash 2025-03-14           22.323054
# 10    AZK.MC                            Azkoyen 2025-03-14           20.129875
# 11    MDF.MC                      Duro Felguera 2025-03-14           15.682653
# 12   OHLA.MC                               OHLA 2025-03-14           15.299329
# 13  AEDAS.MC                        AEDAS Homes 2025-03-14            9.142856
# 14    GSJ.MC                           San José 2025-03-14            5.363989
# 15    RIO.MC                   Bodegas Riojanas 2025-03-14            4.848488
# 16    MCM.MC                    Miquel y Costas 2025-03-14            4.382472
# 17    NTH.MC                  Naturhouse Health 2025-03-14            3.550292
# 18    OLE.MC                             Deoleo 2025-03-14            1.871657
# 19    GAM.MC  General de alquiler de maquinaria 2025-03-14            1.581026
# 20    LRE.MC                         Lar España 2025-02-13            0.606798
# 21    DOM.MC             Global Dominion Access 2025-03-14            0.000000
# 22    SOL.MC                       Soltec Power 2025-03-13            0.000000
# 23   ENER.MC                            Ecoener 2025-03-14           -3.375524
# 24    NXT.MC                             NEXTIL 2025-03-14           -7.532464
# 25    UBS.MC                              URBAS 2025-03-14          -11.111109
# 26    ADX.MC                   Audax Renovables 2025-03-14          -11.151956
# 27   HOME.MC                       Neinor Homes 2025-03-14          -14.069369
# 28    ECR.MC                             Ercros 2025-03-14          -19.067795

# %%
# Create also table of daily returns
list = []

for stock in tqdm(index_list):
    f = os.path.join("../input",stock)
    df = pd.read_csv(f+".csv",index_col="Date",parse_dates=True)
    df['Daily_Return'] = daily_return(df["Adj Close"].loc[year])
    list.append([df.loc[year].tail(1).index.item(),stock.split('.csv')[0],df["Daily_Return"].loc[year].iloc[-1]])


cum = pd.DataFrame(list, columns=['Date','Ticker','Daily_Return'])
cum = wiki[['Ticker','Name']].merge(cum,on='Ticker')
cum.sort_values(by=['Daily_Return'],ignore_index=True, ascending=False).head(40)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
#       Ticker                               Name       Date  Daily_Return
# 0     MDF.MC                      Duro Felguera 2025-03-14     15.257342
# 1     TRG.MC                     Tubos Reunidos 2025-03-14      6.291399
# 2   AEDAS.MC                        AEDAS Homes 2025-03-14      2.321427
# 3     REN.MC                  Renta Corporación 2025-03-14      2.266996
# 4     AMP.MC                              Amper 2025-03-14      1.982994
# 5     NEA.MC                     Nicolás Correa 2025-03-14      1.914897
# 6     DOM.MC             Global Dominion Access 2025-03-14      1.798559
# 7    HOME.MC                       Neinor Homes 2025-03-14      1.639346
# 8     ADX.MC                   Audax Renovables 2025-03-14      1.398608
# 9     ORY.MC                    Oryzon Genomics 2025-03-14      1.234563
# 10   OHLA.MC                               OHLA 2025-03-14      1.167312
# 11    ECR.MC                             Ercros 2025-03-14      1.058200
# 12   CASH.MC                      Prosegur Cash 2025-03-14      1.049480
# 13    MCM.MC                    Miquel y Costas 2025-03-14      0.383143
# 14     AI.MC                        Airtificial 2025-03-14      0.161815
# 15    UBS.MC                              URBAS 2025-03-14      0.000000
# 16    LRE.MC                         Lar España 2025-02-13      0.000000
# 17    GSJ.MC                           San José 2025-03-14      0.000000
# 18    SOL.MC                       Soltec Power 2025-03-13      0.000000
# 19    BKY.MC                   Berkeley Energía 2025-03-14     -0.194172
# 20    OLE.MC                             Deoleo 2025-03-14     -0.261777
# 21    NTH.MC                  Naturhouse Health 2025-03-14     -0.284900
# 22   ENER.MC                            Ecoener 2025-03-14     -0.434782
# 23    NXT.MC                             NEXTIL 2025-03-14     -1.111113
# 24    GAM.MC  General de alquiler de maquinaria 2025-03-14     -1.153845
# 25    AZK.MC                            Azkoyen 2025-03-14     -1.333332
# 26    PRS.MC                              Prisa 2025-03-14     -2.512560
# 27    DIA.MC                                DIA 2025-03-14     -2.777778
# 28    RIO.MC                   Bodegas Riojanas 2025-03-14     -2.808986
